# %%
import numpy as np
import matplotlib.pyplot
import pandas as pd

# %%
members_data = pd.read_csv("Examensarbete_Memberdata_SE.csv")

# %%
members_data
# Out:
#          CustomerKey CustomerRegistrationDate CustomerAnonymizationDate  \
# 0            7427772               2020-03-08                1900-01-01
# 1            7427794               2015-01-10                1900-01-01
# 2            7427797               2016-02-28                1900-01-01
# 3            7427829               2016-05-21                2024-06-13
# 4            7427853               2020-03-08                1900-01-01
# ...              ...                      ...                       ...
# 4857168     16105153               2023-06-22                1900-01-01
# 4857169     16105161               2023-06-22                1900-01-01
# 4857170     16105179               2023-06-22                1900-01-01
# 4857171     16105213               2023-06-22                1900-01-01
# 4857172     16105221               2023-06-22                1900-01-01
#
#          CustomerPostalCode CustomerPostalCity CustomerRegistrationCountry  \
# ...

# %%
transactions = pd.read_csv("2023_transaktioner/CG_ExamensArbete_Transactions_2023_12.csv")
transactions
# Out:
#          CustomerKey      TransactionDate  SalesTransactionKey  \
# 0            3603768  2023-12-13 00:00:00            772042146
# 1            3603768  2023-12-13 00:00:00            772042146
# 2            3603807  2023-12-09 00:00:00            771423261
# 3            3603821  2023-12-02 00:00:00            770095657
# 4            3603821  2023-12-04 00:00:00            770590507
# ...              ...                  ...                  ...
# 4029163     15568215  2023-12-23 00:00:00            774164799
# 4029164     15568215  2023-12-23 00:00:00            774164799
# 4029165     15568330  2023-12-26 00:00:00            774382824
# 4029166     15568330  2023-12-26 00:00:00            774382824
# 4029167     15568330  2023-12-26 00:00:00            774382824
#
#          SalesTransactionLineKey RetailChannelType  \
# 0                     1805246589      Retail store
# 1                     1805267019      Retail store
# 2                     1803709677      Retail store
# ...

# %%
transactions_2024 = pd.read_csv("2024_transaktioner/CG_ExamensArbete_Transactions_2024_12.csv")
transactions_2024
# Out:
#          CustomerKey      TransactionDate  SalesTransactionKey  \
# 0             861111  2024-12-02 00:00:00            810912444
# 1             861111  2024-12-02 00:00:00            810912444
# 2             861111  2024-12-02 00:00:00            810912444
# 3             861111  2024-12-02 00:00:00            810912444
# 4             861111  2024-12-03 00:00:00            811119042
# ...              ...                  ...                  ...
# 4433010       726902  2024-12-14 00:00:00            813280242
# 4433011       726922  2024-12-15 00:00:00            813397580
# 4433012       726922  2024-12-15 00:00:00            813397580
# 4433013       726922  2024-12-15 00:00:00            813397580
# 4433014       726922  2024-12-15 00:00:00            813397580
#
#          SalesTransactionLineKey RetailChannelType  \
# 0                     1893287739      Retail store
# 1                     1893295313      Retail store
# 2                     1893303340      Retail store
# ...
